# %% [markdown]
# <a href="https://colab.research.google.com/github/PanicJoker03/practicas-python/blob/main/Pr%C3%A1ctica_2_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FUNDAMENTOS Y APLICACIONES DE INTELIGENCIA ARTIFICIAL

# %%
print("hello world")
# Out:
# hello world
