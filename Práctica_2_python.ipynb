# %% [markdown]
# <a href="https://colab.research.google.com/github/PanicJoker03/practicas-python/blob/primer_rama/Pr%C3%A1ctica_2_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FUNDAMENTOS Y APLICACIONES DE INTELIGENCIA ARTIFICIAL

# %% [markdown]
# UNIVERSIDAD TECMILENIO
# LUIS CARLOS NÚÑEZ GUERRA
# ACTIVIDAD 4, PARTE 2

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world 2")
# Out:
# hello world

# %%
# Calculadora simple
a = int(input("Ingrese el primer número: "))
b = int(input("Ingrese el segundo número: "))

print("Suma: ", a + b)
# Out:
# Ingrese el primer número: 1
# Ingrese el segundo número: 2
# Suma:  3
